# %% [markdown]
# # 1. Démo endpoint */test_task_assigner_with_random_data/*
#
# Cet endpoint réalise la même tâche que l'endpoint */task_assigner/* mais avec des données générées aléatoirement.

# %% [markdown]
# ## 1.1 Appel de l'API

# %%
import requests
req = requests.get(url="http://127.0.0.1:8000/test_task_assigner_with_random_data")

import simplejson
ans = simplejson.loads(req.json())

# %% [markdown]
# ## 1.2 l'API renvoie un fichier json avec deux clés

# %%
for key in ans.keys():
    print('Clé:', key+ '. Type valeur:', type(ans[key]))
# Out:
# Clé: validite_solution. Type valeur: <class 'bool'>
# Clé: solution. Type valeur: <class 'dict'>

# %% [markdown]
# ## 1.3 La clé _validite_solution_ est le résultat de la vérification mathématique de la solution proposée

# %%
ans['validite_solution']
# Out:
# True

# %% [markdown]
# ## 1.4 La clé *solution* contient la solution au problème, et des statistiques la décrivant

# %%
import pandas as pd
solution = ans["solution"]
pd.DataFrame(solution['solution_brute']).head(10)
# Out:
#     prj   tsk           utl  duree_assignee  tsk_lgt  duree_non_assignee  \
# 0  1182  1202          4059            1.00     2.00                1.00
# 1  1182  1202  not assigned            1.00     2.00                1.00
# 2  1182  2081          3238            2.25     3.75                1.50
# 3  1182  2081          7146            1.50     3.75                2.25
# 4  1182  2834          8329            3.00     3.00                0.00
# 5  1182  4787          1130            0.25     1.75                1.50
# 6  1182  4787          6575            1.50     1.75                0.25
# 7  1182  5076          7146            2.25     2.25                0.00
# 8  1182  7100          7786            2.75     2.75                0.00
# 9  1182  9107          1978            2.50     2.50                0.00
#
#    dsp_utl   cmp  lvl
# 0        8  7954  0.0
# 1      393  7954  NaN
# 2        5  8881  2.0
# 3        9  8881  3.0
# 4       12  8926  1.0
# 5        8  4188  2.0
# 6       13  4188  1.0
# 7        9  7409  3.0
# 8       10  7081  1.0
# 9        8  8018  1.0

# %% [markdown]
# - > On voit par projet, par tâches, comment elles ont été assignées entre les utilisateurs.

# %% [markdown]
# ## 1.5 Statistiques exploratoires - par utilisateur

# %%
pd.DataFrame(solution['statistics']['utl']).head(10)
# Out:
#     utl  niveau_moyen_execution_tsk  total_h_assignees  dsp_utl  \
# 0   723                         3.0                9.0        9
# 1  1130                         2.0                8.0        8
# 2  1150                         1.9                6.0        6
# 3  1978                         1.0                8.0        8
# 4  2181                         3.0                8.0        8
# 5  2417                         2.0                6.0        6
# 6  2476                         3.0                8.0        8
# 7  2480                         1.0                8.0        8
# 8  2874                         2.0                9.0        9
# 9  2996                         2.0                7.0        7
#
#    taux_occupation
# 0              1.0
# 1              1.0
# 2              1.0
# 3              1.0
# 4              1.0
# 5              1.0
# 6              1.0
# 7              1.0
# 8              1.0
# 9              1.0

# %% [markdown]
# ## 1.5 Statistiques exploratoires - par compétence

# %%
pd.DataFrame(solution['statistics']['cmp']).head(10)
# Out:
#     cmp  niveau_cmp_moyen_par_h_realisee  total_h_non_assignees
# 0  6332                             2.38                   6.75
# 1  9115                             1.42                   6.50
# 2  8926                             1.19                   5.50
# 3  7954                             0.25                   4.25
# 4  7382                             2.25                   0.00
# 5  8881                             2.20                   0.00
# 6  8337                             2.20                   0.00
# 7  8020                             2.25                   0.00
# 8  8018                             2.33                   0.00
# 9  7409                             1.86                   0.00

# %% [markdown]
# ## 1.5 Statistiques exploratoires - par projet

# %%
pd.DataFrame(solution['statistics']['prj']).head(10)
# Out:
#      prj  total_h_non_assignees  n_missing_cmp_per_prj
# 6   4835                  25.75                      1
# 14  8979                  16.75                      1
# 9   7243                  16.25                      0
# 10  7458                  12.00                      1
# 2   3376                  10.50                      0
# 4   4010                  10.50                      0
# 5   4267                  10.25                      0
# 7   5050                   9.50                      0
# 13  8895                   8.75                      3
# 11  7483                   7.75                      1

# %% [markdown]
# ## 1.5 Statistiques exploratoires - par tâches

# %%
pd.DataFrame(solution['statistics']['tsk']).head(10)
# Out:
#      utl  n_utl_per_tsk  pct_assignation_tache
# 69  5280              0                      0
# 26  2331              0                      0
# 84  6151              0                      0
# 13  1842              0                      0
# 12  1840              0                      0
# 8   1670              0                      0
# 9   1674              1                      5
# 18  2022              1                     10
# 1   1202              1                     50
# 75  5505              1                    100
