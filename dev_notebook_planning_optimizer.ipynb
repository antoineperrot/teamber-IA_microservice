# %% [markdown]
# ### development data:

# %%
url = 'https://development.api.wandeed.com/api/lst/search?offset=0&limit=500'
access_token = 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJydXRUeHJ5dlltOUVZcGhpRjRxak45ajFvTktLNnU4YUhuM1QySFFSUU5FIn0.....TQih5SGeV2fsitnmnvDLbjFYTh5US0s3c9q8wWShC9ts0XEQSaOQA_7_ssXNPoPGIp-8v8sL7h7GMUKIUDiyHau9Ko43YhabzhM7xmXRTEci75eNkplnTIMEmQb2XMzwkGoOV4pLjQN4eVOJtwokso8BrLMgEExO5A8kAAPjL_bTgl3hC3AZLUL4Xhkjs0jrsZdD_57V4heyhwCJqg1HCHtDkHrTLx95EZeaRQ-fpTJrLzPHo_E7ce-EL8PMoPpySUpKBpIsn_C02bG1sET7TgbbkLX172rCI_xa1kNMXbKCgB3eEerGNxPh52Af_Bu4DJGam5ie4y72ImaAb4Japw'
headers={'Authorization': f'{access_token}',
          'Content-Type':'application/json'}

# %% [markdown]
# ### teamber data:

# %%
url = 'https://teamber.api.wandeed.com/api/lst/search?offset=0&limit=500'
access_token = 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJLQ01VZlkwNDZJSF9vOFo2SmUzaUF2cTRXc21yQkFrdGRTU18wZjNzMmlzIn0.....GsPHRF4LsKvF3MpOzXcoarOqGP52ul39Xkf99ZrmBpsimkicyBv0B_mhWWxK_WEXfaqyW-GxC6SoaDjON8r_HU5rjyfXfL1fSx7Ll24KMqh_Yv3bZkPyeSuBP6aZvKXIerAr8JkkHkOsk9vwiJ91197oTyFRcJ5bdXMalk-siv87K7ui9-yJO_tdeG1054xTielKILT0wsHvXadZARqEPkfNC0htMzlFElSXOCCRgd_6j6KBJYag7ptwnywuBOD2lsF0Cp0MuIkxXaL2Msyf9HHt1wZr9rWYSZafBx6YJZVRDzH52S3kULqwfEF3qsgiQd6__PdCjtsLR4GONmIeow'
headers={'Authorization': f'{access_token}',
             'Content-Type':'application/json'}

# %% [markdown]
# ## requêtes pour les tâches non planifiées :

# %%
datein_isoformat  = "2022-10-03T06:31:00.000Z"
dateout_isoformat = "2022-10-07T07:00:00.000Z"
id_utl = 10

from api.data_fetcher import get_data_planning_optimizer

# %%
data = get_data_planning_optimizer(access_token, datein_isoformat, dateout_isoformat, url=url)

# %%
from api.data_handling.planning_optimizer.handling_input_data import split_data_planning_optimizer
from api.data_handling.planning_optimizer.horaires import make_horaire_clean
from api.data_handling.planning_optimizer.taches import make_clean_task, map_priorite

df_imp, df_hor, df_tsk = split_data_planning_optimizer(data)

# dict_hor = make_horaire_clean(df_hor)
df_tsk = make_clean_task(df_tsk)

# %%
from module.tests.planning_optimizer.data_mocker import mock_dict_priorites_projets
dict_prio = mock_dict_priorites_projets(df_tsk)

df_tsk = map_priorite(df_tsk, dict_prio)

# %%
from module.planning_optimizer.tools.horaires import make_df_ph

# %%
help(make_df_ph)
# Out:
# Help on function make_df_ph in module module.planning_optimizer.tools.horaires:
#
# make_df_ph(plages_horaires_df: pandas.core.frame.DataFrame, date_debut: str, date_fin: str) -> pandas.core.frame.DataFrame
#     :param plages_horaires_df: pd.DataFrame des horaires d'un utilisateur
#     :param date_debut: str au format ISO, date de début du sprint
#     :param date_fin: str au format ISO, date de fin du sprint

# %%
dict_hor[311]
# Out:
#    eeh_sfkperiode eeh_xheuredebut eeh_xheurefin
# 0               0           06:30         10:30
# 1               0           11:30         15:30
# 2               1           06:30         10:30
# 3               1           11:30         15:30
# 4               2           06:30         10:30
# 5               2           11:30         15:30
# 6               3           06:30         10:30
# 7               3           10:30         15:30
# 8               4           07:00         10:00

# %%
make_df_ph(dict_hor[311], datein_isoformat, dateout_isoformat).to_dict()
# Out:
# {'timestamp_debut': {0: Timestamp('2022-10-03 06:31:00+0000', tz='UTC'),
#   1: Timestamp('2022-10-03 11:30:00+0000', tz='UTC'),
#   2: Timestamp('2022-10-04 06:30:00+0000', tz='UTC'),
#   3: Timestamp('2022-10-04 11:30:00+0000', tz='UTC'),
#   4: Timestamp('2022-10-05 06:30:00+0000', tz='UTC'),
#   5: Timestamp('2022-10-05 11:30:00+0000', tz='UTC'),
#   6: Timestamp('2022-10-06 06:30:00+0000', tz='UTC'),
#   7: Timestamp('2022-10-06 10:30:00+0000', tz='UTC')},
#  'timestamp_fin': {0: Timestamp('2022-10-03 10:30:00+0000', tz='UTC'),
#   1: Timestamp('2022-10-03 15:30:00+0000', tz='UTC'),
#   2: Timestamp('2022-10-04 10:30:00+0000', tz='UTC'),
#   3: Timestamp('2022-10-04 15:30:00+0000', tz='UTC'),
#   4: Timestamp('2022-10-05 10:30:00+0000', tz='UTC'),
#   5: Timestamp('2022-10-05 15:30:00+0000', tz='UTC'),
#   6: Timestamp('2022-10-06 10:30:00+0000', tz='UTC'),
#   7: Timestamp('2022-10-06 15:30:00+0000', tz='UTC')}}

# %%
"""
Module de test de la fonction de construction 
"""
import unittest
import pandas as pd
from pandas import Timestamp


class TestMakeDfPh(unittest.TestLoader):
    def setUp(self):
        self.dates_debut = []
        self.dates_fin = []
        self.df_horaires = []
        self.expected_results = []
        
        # cas 1
        self.dates_debut.append("2022-10-01T06:00:00.000Z")
        self.dates_fin.append("2022-10-06T08:00:00.000Z")
        self.df_horaires.append(pd.DataFrame({'eeh_sfkperiode': {0: 0, 1: 0, 2: 1, 3: 1, 4: 2, 5: 2, 6: 3, 7: 3, 8: 4},
                                             'eeh_xheuredebut': {0: '06:30',
                                              1: '11:30',
                                              2: '06:30',
                                              3: '11:30',
                                              4: '06:30',
                                              5: '11:30',
                                              6: '06:30',
                                              7: '10:30',
                                              8: '07:00'},
                                             'eeh_xheurefin': {0: '10:30',
                                              1: '15:30',
                                              2: '10:30',
                                              3: '15:30',
                                              4: '10:30',
                                              5: '15:30',
                                              6: '10:30',
                                              7: '15:30',
                                              8: '10:00'}}))
        self.expected_results.append(pd.DataFrame({'timestamp_debut': 
                                                   {0: Timestamp('2022-10-03 06:30:00+0000', tz='UTC'),
                                                  1: Timestamp('2022-10-03 11:30:00+0000', tz='UTC'),
                                                  2: Timestamp('2022-10-04 06:30:00+0000', tz='UTC'),
                                                  3: Timestamp('2022-10-04 11:30:00+0000', tz='UTC'),
                                                  4: Timestamp('2022-10-05 06:30:00+0000', tz='UTC'),
                                                  5: Timestamp('2022-10-05 11:30:00+0000', tz='UTC'),
                                                  6: Timestamp('2022-10-06 06:30:00+0000', tz='UTC')},
                                                 'timestamp_fin': {0: Timestamp('2022-10-03 10:30:00+0000', tz='UTC'),
                                                  1: Timestamp('2022-10-03 15:30:00+0000', tz='UTC'),
                                                  2: Timestamp('2022-10-04 10:30:00+0000', tz='UTC'),
                                                  3: Timestamp('2022-10-04 15:30:00+0000', tz='UTC'),
                                                  4: Timestamp('2022-10-05 10:30:00+0000', tz='UTC'),
                                                  5: Timestamp('2022-10-05 15:30:00+0000', tz='UTC'),
                                                  6: Timestamp('2022-10-06 08:00:00+0000', tz='UTC')}}))
        
        
        # cas 2
        self.dates_debut.append("2022-10-03T06:31:00.000Z")
        self.dates_fin.append("2022-10-06T08:00:00.000Z")
        self.df_horaires.append(pd.DataFrame({'eeh_sfkperiode': {0: 0, 1: 0, 2: 1, 3: 1, 4: 2, 5: 2, 6: 3, 7: 3, 8: 4},
                                             'eeh_xheuredebut': {0: '06:30',
                                              1: '11:30',
                                              2: '06:30',
                                              3: '11:30',
                                              4: '06:30',
                                              5: '11:30',
                                              6: '06:30',
                                              7: '10:30',
                                              8: '07:00'},
                                             'eeh_xheurefin': {0: '10:30',
                                              1: '15:30',
                                              2: '10:30',
                                              3: '15:30',
                                              4: '10:30',
                                              5: '15:30',
                                              6: '10:30',
                                              7: '15:30',
                                              8: '10:00'}}))
        self.expected_results.append(pd.DataFrame({'timestamp_debut': 
                                                {0: Timestamp('2022-10-03 06:31:00+0000', tz='UTC'),
                                                  1: Timestamp('2022-10-03 11:30:00+0000', tz='UTC'),
                                                  2: Timestamp('2022-10-04 06:30:00+0000', tz='UTC'),
                                                  3: Timestamp('2022-10-04 11:30:00+0000', tz='UTC'),
                                                  4: Timestamp('2022-10-05 06:30:00+0000', tz='UTC'),
                                                  5: Timestamp('2022-10-05 11:30:00+0000', tz='UTC'),
                                                  6: Timestamp('2022-10-06 06:30:00+0000', tz='UTC')},
                                                 'timestamp_fin': {0: Timestamp('2022-10-03 10:30:00+0000', tz='UTC'),
                                                  1: Timestamp('2022-10-03 15:30:00+0000', tz='UTC'),
                                                  2: Timestamp('2022-10-04 10:30:00+0000', tz='UTC'),
                                                  3: Timestamp('2022-10-04 15:30:00+0000', tz='UTC'),
                                                  4: Timestamp('2022-10-05 10:30:00+0000', tz='UTC'),
                                                  5: Timestamp('2022-10-05 15:30:00+0000', tz='UTC'),
                                                  6: Timestamp('2022-10-06 08:00:00+0000', tz='UTC')}}))
        
        # cas 3
        self.dates_debut.append("2022-10-03T06:31:00.000Z")
        self.dates_fin.append("2022-10-06T15:30:00.000Z")
        self.df_horaires.append(pd.DataFrame({'eeh_sfkperiode': {0: 0, 1: 0, 2: 1, 3: 1, 4: 2, 5: 2, 6: 3, 7: 3, 8: 4},
                                             'eeh_xheuredebut': {0: '06:30',
                                              1: '11:30',
                                              2: '06:30',
                                              3: '11:30',
                                              4: '06:30',
                                              5: '11:30',
                                              6: '06:30',
                                              7: '10:30',
                                              8: '07:00'},
                                             'eeh_xheurefin': {0: '10:30',
                                              1: '15:30',
                                              2: '10:30',
                                              3: '15:30',
                                              4: '10:30',
                                              5: '15:30',
                                              6: '10:30',
                                              7: '15:30',
                                              8: '10:00'}}))
        self.expected_results.append(pd.DataFrame({'timestamp_debut': {0: Timestamp('2022-10-03 06:31:00+0000', tz='UTC'),
                                                                      1: Timestamp('2022-10-03 11:30:00+0000', tz='UTC'),
                                                                      2: Timestamp('2022-10-04 06:30:00+0000', tz='UTC'),
                                                                      3: Timestamp('2022-10-04 11:30:00+0000', tz='UTC'),
                                                                      4: Timestamp('2022-10-05 06:30:00+0000', tz='UTC'),
                                                                      5: Timestamp('2022-10-05 11:30:00+0000', tz='UTC'),
                                                                      6: Timestamp('2022-10-06 06:30:00+0000', tz='UTC'),
                                                                      7: Timestamp('2022-10-06 10:30:00+0000', tz='UTC')},
                                                                     'timestamp_fin': {0: Timestamp('2022-10-03 10:30:00+0000', tz='UTC'),
                                                                      1: Timestamp('2022-10-03 15:30:00+0000', tz='UTC'),
                                                                      2: Timestamp('2022-10-04 10:30:00+0000', tz='UTC'),
                                                                      3: Timestamp('2022-10-04 15:30:00+0000', tz='UTC'),
                                                                      4: Timestamp('2022-10-05 10:30:00+0000', tz='UTC'),
                                                                      5: Timestamp('2022-10-05 15:30:00+0000', tz='UTC'),
                                                                      6: Timestamp('2022-10-06 10:30:00+0000', tz='UTC'),
                                                                      7: Timestamp('2022-10-06 15:30:00+0000', tz='UTC')}}))
        
        # cas 4
        self.dates_debut.append("2022-10-03T06:31:00.000Z")
        self.dates_fin.append("2022-10-06T10:30:00.000Z")
        self.df_horaires.append(pd.DataFrame({'eeh_sfkperiode': {0: 0, 1: 0, 2: 1, 3: 1, 4: 2, 5: 2, 6: 3, 7: 3, 8: 4},
                                             'eeh_xheuredebut': {0: '06:30',
                                              1: '11:30',
                                              2: '06:30',
                                              3: '11:30',
                                              4: '06:30',
                                              5: '11:30',
                                              6: '06:30',
                                              7: '10:30',
                                              8: '07:00'},
                                             'eeh_xheurefin': {0: '10:30',
                                              1: '15:30',
                                              2: '10:30',
                                              3: '15:30',
                                              4: '10:30',
                                              5: '15:30',
                                              6: '10:30',
                                              7: '15:30',
                                              8: '10:00'}}))
        self.expected_results.append(pd.DataFrame({'timestamp_debut': {0: Timestamp('2022-10-03 06:31:00+0000', tz='UTC'),
                                                  1: Timestamp('2022-10-03 11:30:00+0000', tz='UTC'),
                                                  2: Timestamp('2022-10-04 06:30:00+0000', tz='UTC'),
                                                  3: Timestamp('2022-10-04 11:30:00+0000', tz='UTC'),
                                                  4: Timestamp('2022-10-05 06:30:00+0000', tz='UTC'),
                                                  5: Timestamp('2022-10-05 11:30:00+0000', tz='UTC'),
                                                  6: Timestamp('2022-10-06 06:30:00+0000', tz='UTC')},
                                                 'timestamp_fin': {0: Timestamp('2022-10-03 10:30:00+0000', tz='UTC'),
                                                  1: Timestamp('2022-10-03 15:30:00+0000', tz='UTC'),
                                                  2: Timestamp('2022-10-04 10:30:00+0000', tz='UTC'),
                                                  3: Timestamp('2022-10-04 15:30:00+0000', tz='UTC'),
                                                  4: Timestamp('2022-10-05 10:30:00+0000', tz='UTC'),
                                                  5: Timestamp('2022-10-05 15:30:00+0000', tz='UTC'),
                                                  6: Timestamp('2022-10-06 10:30:00+0000', tz='UTC')}}))
        
        # cas 5
        self.dates_debut.append("2022-10-03T06:31:00.000Z")
        self.dates_fin.append("2022-10-07T07:00:00.000Z")
        self.df_horaires.append(pd.DataFrame({'eeh_sfkperiode': {0: 0, 1: 0, 2: 1, 3: 1, 4: 2, 5: 2, 6: 3, 7: 3, 8: 4},
                                             'eeh_xheuredebut': {0: '06:30',
                                              1: '11:30',
                                              2: '06:30',
                                              3: '11:30',
                                              4: '06:30',
                                              5: '11:30',
                                              6: '06:30',
                                              7: '10:30',
                                              8: '07:00'},
                                             'eeh_xheurefin': {0: '10:30',
                                              1: '15:30',
                                              2: '10:30',
                                              3: '15:30',
                                              4: '10:30',
                                              5: '15:30',
                                              6: '10:30',
                                              7: '15:30',
                                              8: '10:00'}}))
        self.expected_results.append(pd.DataFrame({'timestamp_debut': {0: Timestamp('2022-10-03 06:31:00+0000', tz='UTC'),
  1: Timestamp('2022-10-03 11:30:00+0000', tz='UTC'),
  2: Timestamp('2022-10-04 06:30:00+0000', tz='UTC'),
  3: Timestamp('2022-10-04 11:30:00+0000', tz='UTC'),
  4: Timestamp('2022-10-05 06:30:00+0000', tz='UTC'),
  5: Timestamp('2022-10-05 11:30:00+0000', tz='UTC'),
  6: Timestamp('2022-10-06 06:30:00+0000', tz='UTC'),
  7: Timestamp('2022-10-06 10:30:00+0000', tz='UTC')},
 'timestamp_fin': {0: Timestamp('2022-10-03 10:30:00+0000', tz='UTC'),
  1: Timestamp('2022-10-03 15:30:00+0000', tz='UTC'),
  2: Timestamp('2022-10-04 10:30:00+0000', tz='UTC'),
  3: Timestamp('2022-10-04 15:30:00+0000', tz='UTC'),
  4: Timestamp('2022-10-05 10:30:00+0000', tz='UTC'),
  5: Timestamp('2022-10-05 15:30:00+0000', tz='UTC'),
  6: Timestamp('2022-10-06 10:30:00+0000', tz='UTC'),
  7: Timestamp('2022-10-06 15:30:00+0000', tz='UTC')}}))


    def test(self):
        
        for date_debut, date_fin, df_hor, expected_result in zip(self.dates_debut,
                                               self.dates_fin,
                                               self.df_horaires,
                                               self.expected_results):
            output_func = make_df_ph(df_hor, date_debut, date_fin)
            pd.testing.assert_frame_equal(output_func, expected_result)
            
t = TestMakeDfPh()
t.setUp()
t.test()
